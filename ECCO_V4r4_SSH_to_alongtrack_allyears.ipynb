# %%
import s3fs
import h5py
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import requests
import boto3
import s3fs
from os.path import dirname, join
from pprint import pprint
from pyresample import kd_tree, geometry, utils
from pyresample.geometry import GridDefinition
from pathlib import Path
import os

# %% [markdown]
# ### Confirm Existence of .netrc file in your home directory

# %%
# make a .netrc file in your home directory with the following
# machine urs.earthdata.nasa.gov login ifenty password XCfK5QhgEGuWVgu4qRuH
# for login and password use your EarthData login

# if this command returns 1, you are good

# %%
# !cat ~/.netrc | grep 'urs.earthdata.nasa.gov' | wc -l
# Out:
# 1

# %% [markdown]
# ### Get credentials

# %%
# %%capture
import requests

def store_aws_keys(endpoint: str="https://archive.podaac.earthdata.nasa.gov/s3credentials"):    
    with requests.get(endpoint, "w") as r:
        accessKeyId, secretAccessKey, sessionToken, expiration = list(r.json().values())

    creds ={}
    creds['AccessKeyId'] = accessKeyId
    creds['SecretAccessKey'] = secretAccessKey
    creds['SessionToken'] = sessionToken
    creds['expiration'] = expiration
    
    return creds

creds = store_aws_keys()
print(creds)

# %%
print(f"\nThe current session token expires at {creds['expiration']}.\n")
# Out:
# The current session token expires at 2022-03-19 00:02:48+00:00.

# %% [markdown]
# # Define important params

# %%
# ECCO Starts on Jan 1, 1992
ECCO_start_time= np.datetime64('1992-01-01')
alongtrack_file_dir = Path('/home/jovyan/ECCO_GMSL')

# output directory
output_dir=Path('/home/jovyan/Data/ECCO_GMSL/ECCO_V4r4_alongtrack_output')
output_dir.mkdir(exist_ok=True)

# %% [markdown]
# # Make a map of grid cell areas and calculate total ocean area
#
# needed to calculate 'true' global mean sea level from ECCO

# %% [markdown]
# ## Download the ECCO grid geometry file locally

# %%
# subroutine to download a file from S3 to the local machine
def download(source: str):
    target = os.path.basename(source.split("?")[0])
    
    if not os.path.isfile(target):
        # !wget --quiet --continue --output-document $target $source
    
    return target

# %%
ECCO_grid_url = "https://archive.podaac.earthdata.nasa.gov/podaac-ops-cumulus-protected/ECCO_L4_GEOMETRY_05DEG_V4R4/GRID_GEOMETRY_ECCO_V4r4_latlon_0p50deg.nc"
ECCO_grid_file = download(ECCO_grid_url)
ECCO_grid = xr.open_dataset(ECCO_grid_file)

print(ECCO_grid)
# we need the area field
# Out:
# <xarray.Dataset>
# Dimensions:         (Z: 50, latitude: 360, longitude: 720, nv: 2)
# Coordinates:
#   * Z               (Z) float32 -5.0 -15.0 -25.0 ... -5.461e+03 -5.906e+03
#   * latitude        (latitude) float32 -89.75 -89.25 -88.75 ... 89.25 89.75
#   * longitude       (longitude) float32 -179.8 -179.2 -178.8 ... 179.2 179.8
#     latitude_bnds   (latitude, nv) float32 ...
#     longitude_bnds  (longitude, nv) float32 ...
#     Z_bnds          (Z, nv) float32 ...
# Dimensions without coordinates: nv
# Data variables:
#     hFacC           (Z, latitude, longitude) float64 ...
#     Depth           (latitude, longitude) float64 ...
#     area            (latitude, longitude) float64 ...
#     drF             (Z) float32 ...
#     maskC           (Z, latitude, longitude) bool ...
# Attributes: (12/57)
#     acknowledgement:                 This research was carried out by the Jet...
#     author:                          Ian Fenty and Ou Wang
#     cdm_data_type:                   Grid
#     comment:                         Fields provided on a regular lat-lon gri...
#     Conventions:                     CF-1.8, ACDD-1.3
#     coordinates_comment:             Note: the global 'coordinates' attribute...
#     ...                              ...
#     references:                      ECCO Consortium, Fukumori, I., Wang, O.,...
#     source:                          The ECCO V4r4 state estimate was produce...
#     standard_name_vocabulary:        NetCDF Climate and Forecast (CF) Metadat...
#     summary:                         This dataset provides geometric paramete...
#     title:                           ECCO Geometry Parameters for the 0.5 deg...
#     uuid:                            b4795c62-86e5-11eb-9c5f-f8f21e2ee3e0

# %% [markdown]
# ## Make grid cell area for wet points map

# %%
# mask land points
ECCO_ocean_area = ECCO_grid.area*ECCO_grid.maskC[0,:]
ECCO_ocean_area=ECCO_ocean_area.drop('Z')

ECCO_total_ocean_area = ECCO_ocean_area.sum().values

# in km^2
print(f'total ocean area: {np.round(ECCO_total_ocean_area/1e9)} km^2')
ECCO_ocean_area.plot();

plt.title('grid cell area [m^2]');
# Out:
# total ocean area: 358002.0 km^2

# %% [markdown]
# # Find the x,y points for each of the cycle days
#
# ## Load the AlongTrack x,y,t file

# %%
alongtrack = xr.open_dataset(str(alongtrack_file_dir) + '/AlongTrack_sample.nc', decode_times=False)
alongtrack
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 604116)
# Coordinates:
#   * time           (time) float32 0.0 1.0 2.0 ... 8.567e+05 8.567e+05 8.567e+05
# Data variables:
#     x              (time) float32 ...
#     y              (time) float32 ...
#     time_original  (time) float32 ...

# %% [markdown]
# ## Plot the cycle paths

# %%
plt.close()
fig = plt.figure(figsize=(10,5))
ax = plt.axes(projection=ccrs.Robinson( \
              central_longitude=-67, globe=None))
ax.gridlines()
ax.add_feature(cfeature.LAND)
#ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)

kk=10
p=ax.plot(alongtrack.x[::kk],
          alongtrack.y[::kk], 'r.', markersize=0.2,\
          transform=ccrs.PlateCarree())

# plot x,y locations with nan time
ins = np.where(np.isnan(alongtrack.time.values))[0]
p=ax.plot(alongtrack.x.values[ins[::10]],
          alongtrack.y.values[ins[::10]], 'b.', markersize=5,\
          transform=ccrs.PlateCarree())

plt.title('x,y locations for all tracks.  blue=bad time (nan)', fontsize=20)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:825: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:877: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:944: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)

# %% [markdown]
# ## Create a dictionary with x,y points for each of the 10 cycle days

# %%
print(alongtrack.time.min())
print(alongtrack.time.max())
print(len(alongtrack.time))
# Out:
# <xarray.DataArray 'time' ()>
# array(0.)
# <xarray.DataArray 'time' ()>
# array(856657.)
# 604116

# %%
x_track_in_d = {}
y_track_in_d = {}

alongtrack_swath = {}
tc = 0
all_ins = []
for d in range(10):
    d_start = d*86400
    d_end = d_start + 86400
    ins = np.where(np.logical_and(alongtrack.time >= d_start, alongtrack.time < d_end))[0]
    
    all_ins.append(ins) 
    x_track_in_d[d],y_track_in_d[d] = utils.check_and_wrap(alongtrack.x[ins],  alongtrack.y[ins])
    
    print(f'cycle day: {d}, time_start {d_start}s, time_end {d_end}s, number of xy points {len(ins)}')
    
    tc = tc + len(ins)
    # this handy pyresample object will allow us to map from the gridded ECCO fields to the alongtrack points
    alongtrack_swath[d] =  geometry.SwathDefinition(lons=x_track_in_d[d], lats=y_track_in_d[d])
# Out:
# cycle day: 0, time_start 0s, time_end 86400s, number of xy points 59672
# cycle day: 1, time_start 86400s, time_end 172800s, number of xy points 60692
# cycle day: 2, time_start 172800s, time_end 259200s, number of xy points 61151
# cycle day: 3, time_start 259200s, time_end 345600s, number of xy points 60718
# cycle day: 4, time_start 345600s, time_end 432000s, number of xy points 61541
# cycle day: 5, time_start 432000s, time_end 518400s, number of xy points 47217
# cycle day: 6, time_start 518400s, time_end 604800s, number of xy points 60348
# cycle day: 7, time_start 604800s, time_end 691200s, number of xy points 60832
# cycle day: 8, time_start 691200s, time_end 777600s, number of xy points 61097
# cycle day: 9, time_start 777600s, time_end 864000s, number of xy points 57513

# %%
# Note 13,335 time values are Nan!
print(f'number of nan times: {np.sum(np.isnan(alongtrack.time.values))}')
# Out:
# number of nan times: 13335

# %%
# sanity check the range of xy points 
for d in range(10):
    print(f'cycle day {d} min and max longitudes: \
        {np.nanmin(x_track_in_d[d].values), np.nanmax(x_track_in_d[d].values)}')
# Out:
# cycle day 0 min and max longitudes:         (-179.99866, 179.99622)
# cycle day 1 min and max longitudes:         (-179.9978, 179.99731)
# cycle day 2 min and max longitudes:         (-179.99811, 179.99066)
# cycle day 3 min and max longitudes:         (-179.99268, 179.99951)
# cycle day 4 min and max longitudes:         (-179.9971, 179.9989)
# cycle day 5 min and max longitudes:         (-179.99747, 179.99402)
# cycle day 6 min and max longitudes:         (-179.9989, 179.9997)
# cycle day 7 min and max longitudes:         (-179.99136, 179.9993)
# cycle day 8 min and max longitudes:         (-179.98523, 179.99414)
# cycle day 9 min and max longitudes:         (-179.99942, 179.99695)

# %% [markdown]
# ## Plot x,y points for each cycle day with a different color

# %%
fig = plt.figure(figsize=(15,5))
cm = plt.get_cmap('gist_rainbow')
ax = fig.add_subplot(111)

ax = plt.axes(projection=ccrs.Robinson( \
              central_longitude=-67, globe=None))
ax.gridlines()
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.COASTLINE)

kk=10

for d in range(10):
    p=ax.plot(x_track_in_d[d][::kk],
              y_track_in_d[d][::kk],'.', markersize=0.5,\
              transform=ccrs.PlateCarree())

plt.title('note gaps from x,y points where time=nan');
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:825: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:877: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:944: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)

# %% [markdown]
# # Prepare ECCO Daily SSH dataset

# %%
ShortName = "ECCO_L4_SSH_05DEG_DAILY_V4R4B"

# %%
# Ask PODAAC for the collection id
response = requests.get(
    url='https://cmr.earthdata.nasa.gov/search/collections.umm_json', 
    params={'provider': "POCLOUD",
            'ShortName': ShortName,
            'page_size': 1}
)

ummc = response.json()['items'][0]
ccid = ummc['meta']['concept-id']
print(f'collection id: {ccid}')
# Out:
# collection id: C2129181904-POCLOUD

# %% [markdown]
# ## Make a "direct connection" to the S3 file system

# %%
s3 = s3fs.S3FileSystem(
    key=creds['AccessKeyId'],
    secret=creds['SecretAccessKey'],
    token=creds['SessionToken'],
    client_kwargs={'region_name':'us-west-2'},
)

# %%
# make a S3 'filesystem' object
fs = s3fs.S3FileSystem(anon=False,
                      key=creds['AccessKeyId'],
                      secret=creds['SecretAccessKey'],
                      token=creds['SessionToken'])

# %% [markdown]
# ## Make a list of all of the ECCO SSH dataset files for some arbitrary year

# %%
import time

# %%
year = 1992

start_time = time.time()

ECCO_SSH_files = fs.glob(join("podaac-ops-cumulus-protected/", ShortName, '*'+ str(year) + '*.nc'))
print(f'time to find urls: { time.time() - start_time} s')

pprint(ECCO_SSH_files[0:5])
print('...')
pprint(ECCO_SSH_files[-5:])
# Out:
# time to find urls: 5.477067708969116 s
# ['podaac-ops-cumulus-protected/ECCO_L4_SSH_05DEG_DAILY_V4R4B/SEA_SURFACE_HEIGHT_day_mean_1992-01-01_ECCO_V4r4b_latlon_0p50deg.nc',
#  'podaac-ops-cumulus-protected/ECCO_L4_SSH_05DEG_DAILY_V4R4B/SEA_SURFACE_HEIGHT_day_mean_1992-01-02_ECCO_V4r4b_latlon_0p50deg.nc',
#  'podaac-ops-cumulus-protected/ECCO_L4_SSH_05DEG_DAILY_V4R4B/SEA_SURFACE_HEIGHT_day_mean_1992-01-03_ECCO_V4r4b_latlon_0p50deg.nc',
#  'podaac-ops-cumulus-protected/ECCO_L4_SSH_05DEG_DAILY_V4R4B/SEA_SURFACE_HEIGHT_day_mean_1992-01-04_ECCO_V4r4b_latlon_0p50deg.nc',
#  'podaac-ops-cumulus-protected/ECCO_L4_SSH_05DEG_DAILY_V4R4B/SEA_SURFACE_HEIGHT_day_mean_1992-01-05_ECCO_V4r4b_latlon_0p50deg.nc']
# ...
# ['podaac-ops-cumulus-protected/ECCO_L4_SSH_05DEG_DAILY_V4R4B/SEA_SURFACE_HEIGHT_day_mean_1992-12-27_ECCO_V4r4b_latlon_0p50deg.nc',
#  'podaac-ops-cumulus-protected/ECCO_L4_SSH_05DEG_DAILY_V4R4B/SEA_SURFACE_HEIGHT_day_mean_1992-12-28_ECCO_V4r4b_latlon_0p50deg.nc',
#  'podaac-ops-cumulus-protected/ECCO_L4_SSH_05DEG_DAILY_V4R4B/SEA_SURFACE_HEIGHT_day_mean_1992-12-29_ECCO_V4r4b_latlon_0p50deg.nc',
#  'podaac-ops-cumulus-protected/ECCO_L4_SSH_05DEG_DAILY_V4R4B/SEA_SURFACE_HEIGHT_day_mean_1992-12-30_ECCO_V4r4b_latlon_0p50deg.nc',
#  'podaac-ops-cumulus-protected/ECCO_L4_SSH_05DEG_DAILY_V4R4B/SEA_SURFACE_HEIGHT_day_mean_1992-12-31_ECCO_V4r4b_latlon_0p50deg.nc']

# %% [markdown]
# ## Load all of the files for this year from AWS S3 using 'direct connection' and combine into a single xarray DataSet object
#
# Note: this takes a minute.

# %%
# from dask.distributed import Client

# client = Client("tcp://127.0.0.1:38643")
# client

# %%
for year in range(1992,2018):

    start_time = time.time()
    ECCO_SSH_files = fs.glob(join("podaac-ops-cumulus-protected/", ShortName, '*'+ str(year) + '*.nc'))
    paths=[fs.open(f) for f in ECCO_SSH_files]
    
    ECCO_DS_daily = xr.open_mfdataset(
    paths=paths,
    combine='nested',
    concat_dim='time',
    decode_cf=True,
    coords='minimal',
    chunks={'time': 1}  
    )
    ECCO_DS_daily.close()

    ECCO_SSH = ECCO_DS_daily.SSH
    ECCO_lons, ECCO_lats = np.meshgrid(ECCO_SSH.longitude, ECCO_SSH.latitude)
    ECCO_grid_def = GridDefinition(lons=ECCO_lons, lats=ECCO_lats)
    
    # Loop through all days
    for f in range(len(ECCO_SSH.time)):

        # get the date/time associated with this record
        rec_time = ECCO_SSH.time[f]

        # Determine which cycle day we're in
        # ... count how many days since 1992-01-01?
        delta_days = int((rec_time.values - ECCO_start_time)/1e9/86400)

        # ... cycle day is delta_days mod 10
        cycle_day = delta_days % 10

        # print(f'record day of year {str(rec_time.values)[0:10]}, cycle day {cycle_day}')

        # sample the ECCO field at the x,y locations for this cycle day 
        # search within a 200 km radius for the nearest neighbor.
        # (overkill since it's a 1 degree model but just to be safe)

        ECCO_at_xy_points =\
            kd_tree.resample_nearest(ECCO_grid_def, \
                                     ECCO_SSH[f].values, \
                                     alongtrack_swath[cycle_day],\
                                     radius_of_influence=200000)

        # make a new DataArray object
        ECCO_at_xy_points_da = xr.DataArray(ECCO_at_xy_points, dims=['i'])
        ECCO_at_xy_points_da = ECCO_at_xy_points_da.assign_coords({'time':rec_time})
        ECCO_at_xy_points_da = ECCO_at_xy_points_da.assign_coords({'cycle_day':cycle_day})
        ECCO_at_xy_points_da = ECCO_at_xy_points_da.assign_coords({'delta_days':delta_days})
        ECCO_at_xy_points_da = ECCO_at_xy_points_da.assign_coords({'lon':('i', x_track_in_d[cycle_day].values)})
        ECCO_at_xy_points_da = ECCO_at_xy_points_da.assign_coords({'lat':('i', y_track_in_d[cycle_day].values)})
        ECCO_at_xy_points_da.delta_days.attrs['comment'] = 'days since 1992-01-01'
        ECCO_at_xy_points_da.cycle_day.attrs['comment'] = 'which day in 10 day cycle'

        ECCO_at_xy_points_da.name = 'SSH_at_xy'
        ECCO_at_xy_points_da.attrs['source']='ECCO V4r4'

        # Save to Disk
        new_fname = 'ECCO_V4r4_alongtrack_SSH_' + str(rec_time.values).split('T')[0] + '.nc'
        ECCO_at_xy_points_da.to_netcdf(output_dir / new_fname)
    
    print(time.time() - start_time)
# Out:
# record day of year 1992-01-01, cycle day 0
# record day of year 1992-01-02, cycle day 1
# record day of year 1992-01-03, cycle day 2
# record day of year 1992-01-04, cycle day 3
# record day of year 1992-01-05, cycle day 4
# record day of year 1992-01-06, cycle day 5
# record day of year 1992-01-07, cycle day 6
# record day of year 1992-01-08, cycle day 7
# record day of year 1992-01-09, cycle day 8
# record day of year 1992-01-10, cycle day 9
# record day of year 1992-01-11, cycle day 0
# record day of year 1992-01-12, cycle day 1
# record day of year 1992-01-13, cycle day 2
# record day of year 1992-01-14, cycle day 3
# record day of year 1992-01-15, cycle day 4
# record day of year 1992-01-16, cycle day 5
# record day of year 1992-01-17, cycle day 6
# record day of year 1992-01-18, cycle day 7
# record day of year 1992-01-19, cycle day 8
# record day of year 1992-01-20, cycle day 9
# record day of year 1992-01-21, cycle day 0
# record day of year 1992-01-22, cycle day 1
# record day of year 1992-01-23, cycle day 2
# record day of year 1992-01-24, cycle day 3
# record day of year 1992-01-25, cycle day 4
# record day of year 1992-01-26, cycle day 5
# record day of year 1992-01-27, cycle day 6
# record day of year 1992-01-28, cycle day 7
# record day of year 1992-01-29, cycle day 8
# record day of year 1992-01-30, cycle day 9
# record day of year 1992-01-31, cycle day 0
# record day of year 1992-02-01, cycle day 1
# record day of year 1992-02-02, cycle day 2
# record day of year 1992-02-03, cycle day 3
# record day of year 1992-02-04, cycle day 4
# record day of year 1992-02-05, cycle day 5
# record day of year 1992-02-06, cycle day 6
# record day of year 1992-02-07, cycle day 7
# record day of year 1992-02-08, cycle day 8
# record day of year 1992-02-09, cycle day 9
# record day of year 1992-02-10, cycle day 0
# record day of year 1992-02-11, cycle day 1
# record day of year 1992-02-12, cycle day 2
# record day of year 1992-02-13, cycle day 3
# record day of year 1992-02-14, cycle day 4
# record day of year 1992-02-15, cycle day 5
# record day of year 1992-02-16, cycle day 6
# record day of year 1992-02-17, cycle day 7
# record day of year 1992-02-18, cycle day 8
# record day of year 1992-02-19, cycle day 9
# record day of year 1992-02-20, cycle day 0
# record day of year 1992-02-21, cycle day 1
# record day of year 1992-02-22, cycle day 2
# record day of year 1992-02-23, cycle day 3
# record day of year 1992-02-24, cycle day 4
# record day of year 1992-02-25, cycle day 5
# record day of year 1992-02-26, cycle day 6
# record day of year 1992-02-27, cycle day 7
# record day of year 1992-02-28, cycle day 8
# record day of year 1992-02-29, cycle day 9
# record day of year 1992-03-01, cycle day 0
# record day of year 1992-03-02, cycle day 1
# record day of year 1992-03-03, cycle day 2
# record day of year 1992-03-04, cycle day 3
# record day of year 1992-03-05, cycle day 4
# record day of year 1992-03-06, cycle day 5
# record day of year 1994-09-10, cycle day 3
# record day of year 1994-09-11, cycle day 4
# record day of year 1994-09-12, cycle day 5
# record day of year 1994-09-13, cycle day 6
# record day of year 1994-09-14, cycle day 7
# record day of year 1994-09-15, cycle day 8
# record day of year 1994-09-16, cycle day 9
# record day of year 1994-09-17, cycle day 0
# record day of year 1994-09-18, cycle day 1
# record day of year 1994-09-19, cycle day 2
# record day of year 1994-09-20, cycle day 3
# record day of year 1994-09-21, cycle day 4
# record day of year 1994-09-22, cycle day 5
# record day of year 1994-09-23, cycle day 6
# record day of year 1994-09-24, cycle day 7
# record day of year 1994-09-25, cycle day 8
# record day of year 1994-09-26, cycle day 9
# record day of year 1994-09-27, cycle day 0
# record day of year 1994-09-28, cycle day 1
# record day of year 1994-09-29, cycle day 2
# record day of year 1994-09-30, cycle day 3
# record day of year 1994-10-01, cycle day 4
# record day of year 1994-10-02, cycle day 5
# record day of year 1994-10-03, cycle day 6
# record day of year 1994-10-04, cycle day 7
# record day of year 1994-10-05, cycle day 8
# record day of year 1994-10-06, cycle day 9
# record day of year 1994-10-07, cycle day 0
# record day of year 1994-10-08, cycle day 1
# record day of year 1994-10-09, cycle day 2
# record day of year 1994-10-10, cycle day 3
# record day of year 1994-10-11, cycle day 4
# record day of year 1994-10-12, cycle day 5
# record day of year 1994-10-13, cycle day 6
# record day of year 1994-10-14, cycle day 7
# record day of year 1994-10-15, cycle day 8
# record day of year 1994-10-16, cycle day 9
# record day of year 1994-10-17, cycle day 0
# record day of year 1994-10-18, cycle day 1
# record day of year 1994-10-19, cycle day 2
# record day of year 1994-10-20, cycle day 3
# record day of year 1994-10-21, cycle day 4
# record day of year 1994-10-22, cycle day 5
# record day of year 1994-10-23, cycle day 6
# record day of year 1994-10-24, cycle day 7
# record day of year 1994-10-25, cycle day 8
# record day of year 1994-10-26, cycle day 9
# record day of year 1994-10-27, cycle day 0
# record day of year 1994-10-28, cycle day 1
# record day of year 1994-10-29, cycle day 2
# record day of year 1994-10-30, cycle day 3
# record day of year 1994-10-31, cycle day 4
# record day of year 1994-11-01, cycle day 5
# record day of year 1994-11-02, cycle day 6
# record day of year 1994-11-03, cycle day 7
# record day of year 1994-11-04, cycle day 8
# record day of year 1994-11-05, cycle day 9
# record day of year 1994-11-06, cycle day 0
# record day of year 1994-11-07, cycle day 1
# record day of year 1994-11-08, cycle day 2
# record day of year 1994-11-09, cycle day 3
# record day of year 1994-11-10, cycle day 4
# record day of year 1994-11-11, cycle day 5
# record day of year 1994-11-12, cycle day 6
# record day of year 1994-11-13, cycle day 7
# record day of year 1994-11-14, cycle day 8
# record day of year 1994-11-15, cycle day 9
# record day of year 1994-11-16, cycle day 0
# record day of year 1994-11-17, cycle day 1
# record day of year 1994-11-18, cycle day 2
# record day of year 1994-11-19, cycle day 3
# record day of year 1994-11-20, cycle day 4
# record day of year 1994-11-21, cycle day 5
# record day of year 1994-11-22, cycle day 6
# record day of year 1994-11-23, cycle day 7
# record day of year 1994-11-24, cycle day 8
# record day of year 2017-06-18, cycle day 0
# record day of year 2017-06-19, cycle day 1
# record day of year 2017-06-20, cycle day 2
# record day of year 2017-06-21, cycle day 3
# record day of year 2017-06-22, cycle day 4
# record day of year 2017-06-23, cycle day 5
# record day of year 2017-06-24, cycle day 6
# record day of year 2017-06-25, cycle day 7
# record day of year 2017-06-26, cycle day 8
# record day of year 2017-06-27, cycle day 9
# record day of year 2017-06-28, cycle day 0
# record day of year 2017-06-29, cycle day 1
# record day of year 2017-06-30, cycle day 2
# record day of year 2017-07-01, cycle day 3
# record day of year 2017-07-02, cycle day 4
# record day of year 2017-07-03, cycle day 5
# record day of year 2017-07-04, cycle day 6
# record day of year 2017-07-05, cycle day 7
# record day of year 2017-07-06, cycle day 8
# record day of year 2017-07-07, cycle day 9
# record day of year 2017-07-08, cycle day 0
# record day of year 2017-07-09, cycle day 1
# record day of year 2017-07-10, cycle day 2
# record day of year 2017-07-11, cycle day 3
# record day of year 2017-07-12, cycle day 4
# record day of year 2017-07-13, cycle day 5
# record day of year 2017-07-14, cycle day 6
# record day of year 2017-07-15, cycle day 7
# record day of year 2017-07-16, cycle day 8
# record day of year 2017-07-17, cycle day 9
# record day of year 2017-07-18, cycle day 0
# record day of year 2017-07-19, cycle day 1
# record day of year 2017-07-20, cycle day 2
# record day of year 2017-07-21, cycle day 3
# record day of year 2017-07-22, cycle day 4
# record day of year 2017-07-23, cycle day 5
# record day of year 2017-07-24, cycle day 6
# record day of year 2017-07-25, cycle day 7
# record day of year 2017-07-26, cycle day 8
# record day of year 2017-07-27, cycle day 9
# record day of year 2017-07-28, cycle day 0
# record day of year 2017-07-29, cycle day 1
# record day of year 2017-07-30, cycle day 2
# record day of year 2017-07-31, cycle day 3
# record day of year 2017-08-01, cycle day 4
# record day of year 2017-08-02, cycle day 5
# record day of year 2017-08-03, cycle day 6
# record day of year 2017-08-04, cycle day 7
# record day of year 2017-08-05, cycle day 8
# record day of year 2017-08-06, cycle day 9
# record day of year 2017-08-07, cycle day 0
# record day of year 2017-08-08, cycle day 1
# record day of year 2017-08-09, cycle day 2
# record day of year 2017-08-10, cycle day 3
# record day of year 2017-08-11, cycle day 4
# record day of year 2017-08-12, cycle day 5
# record day of year 2017-08-13, cycle day 6
# record day of year 2017-08-14, cycle day 7
# record day of year 2017-08-15, cycle day 8
# record day of year 2017-08-16, cycle day 9
# record day of year 2017-08-17, cycle day 0
# record day of year 2017-08-18, cycle day 1
# record day of year 2017-08-19, cycle day 2
# record day of year 2017-08-20, cycle day 3
# record day of year 2017-08-21, cycle day 4
# record day of year 2017-08-22, cycle day 5
# record day of year 2017-08-23, cycle day 6
# record day of year 2017-08-24, cycle day 7
# record day of year 2017-08-25, cycle day 8
# record day of year 2017-08-26, cycle day 9
# record day of year 2017-08-27, cycle day 0
# record day of year 2017-08-28, cycle day 1
# record day of year 2017-08-29, cycle day 2
# record day of year 2017-08-30, cycle day 3
# record day of year 2017-08-31, cycle day 4
# record day of year 2017-09-01, cycle day 5
# record day of year 2017-09-02, cycle day 6
# record day of year 2017-09-03, cycle day 7
# record day of year 2017-09-04, cycle day 8
# record day of year 2017-09-05, cycle day 9
# record day of year 2017-09-06, cycle day 0
# record day of year 2017-09-07, cycle day 1
# record day of year 2017-09-08, cycle day 2
# record day of year 2017-09-09, cycle day 3
# record day of year 2017-09-10, cycle day 4
# record day of year 2017-09-11, cycle day 5
# record day of year 2017-09-12, cycle day 6
# record day of year 2017-09-13, cycle day 7
# record day of year 2017-09-14, cycle day 8
# record day of year 2017-09-15, cycle day 9
# record day of year 2017-09-16, cycle day 0
# record day of year 2017-09-17, cycle day 1
# record day of year 2017-09-18, cycle day 2
# record day of year 2017-09-19, cycle day 3
# record day of year 2017-09-20, cycle day 4
# record day of year 2017-09-21, cycle day 5
# record day of year 2017-09-22, cycle day 6
# record day of year 2017-09-23, cycle day 7
# record day of year 2017-09-24, cycle day 8
# record day of year 2017-09-25, cycle day 9
# record day of year 2017-09-26, cycle day 0
# record day of year 2017-09-27, cycle day 1
# record day of year 2017-09-28, cycle day 2
# record day of year 2017-09-29, cycle day 3
# record day of year 2017-09-30, cycle day 4
# record day of year 2017-10-01, cycle day 5
# record day of year 2017-10-02, cycle day 6
# record day of year 2017-10-03, cycle day 7
# record day of year 2017-10-04, cycle day 8
# record day of year 2017-10-05, cycle day 9
# record day of year 2017-10-06, cycle day 0
# record day of year 2017-10-07, cycle day 1
# record day of year 2017-10-08, cycle day 2
# record day of year 2017-10-09, cycle day 3
# record day of year 2017-10-10, cycle day 4
# record day of year 2017-10-11, cycle day 5
# record day of year 2017-10-12, cycle day 6
# record day of year 2017-10-13, cycle day 7
# record day of year 2017-10-14, cycle day 8
# record day of year 2017-10-15, cycle day 9
# record day of year 2017-10-16, cycle day 0
# record day of year 2017-10-17, cycle day 1
# record day of year 2017-10-18, cycle day 2
# record day of year 2017-10-19, cycle day 3
# record day of year 2017-10-20, cycle day 4
# record day of year 2017-10-21, cycle day 5
# record day of year 2017-10-22, cycle day 6
# record day of year 2017-10-23, cycle day 7
# record day of year 2017-10-24, cycle day 8
# record day of year 2017-10-25, cycle day 9
# record day of year 2017-10-26, cycle day 0
# record day of year 2017-10-27, cycle day 1
# record day of year 2017-10-28, cycle day 2
# record day of year 2017-10-29, cycle day 3
# record day of year 2017-10-30, cycle day 4
# record day of year 2017-10-31, cycle day 5
# record day of year 2017-11-01, cycle day 6
# record day of year 2017-11-02, cycle day 7
# record day of year 2017-11-03, cycle day 8
# record day of year 2017-11-04, cycle day 9
# record day of year 2017-11-05, cycle day 0
# record day of year 2017-11-06, cycle day 1
# record day of year 2017-11-07, cycle day 2
# record day of year 2017-11-08, cycle day 3
# record day of year 2017-11-09, cycle day 4
# record day of year 2017-11-10, cycle day 5
# record day of year 2017-11-11, cycle day 6
# record day of year 2017-11-12, cycle day 7
# record day of year 2017-11-13, cycle day 8
# record day of year 2017-11-14, cycle day 9
# record day of year 2017-11-15, cycle day 0
# record day of year 2017-11-16, cycle day 1
# record day of year 2017-11-17, cycle day 2
# record day of year 2017-11-18, cycle day 3
# record day of year 2017-11-19, cycle day 4
# record day of year 2017-11-20, cycle day 5
# record day of year 2017-11-21, cycle day 6
# record day of year 2017-11-22, cycle day 7
# record day of year 2017-11-23, cycle day 8
# record day of year 2017-11-24, cycle day 9
# record day of year 2017-11-25, cycle day 0
# record day of year 2017-11-26, cycle day 1
# record day of year 2017-11-27, cycle day 2
# record day of year 2017-11-28, cycle day 3
# record day of year 2017-11-29, cycle day 4
# record day of year 2017-11-30, cycle day 5
# record day of year 2017-12-01, cycle day 6
# record day of year 2017-12-02, cycle day 7
# record day of year 2017-12-03, cycle day 8
# record day of year 2017-12-04, cycle day 9
# record day of year 2017-12-05, cycle day 0
# record day of year 2017-12-06, cycle day 1
# record day of year 2017-12-07, cycle day 2
# record day of year 2017-12-08, cycle day 3
# record day of year 2017-12-09, cycle day 4
# record day of year 2017-12-10, cycle day 5
# record day of year 2017-12-11, cycle day 6
# record day of year 2017-12-12, cycle day 7
# record day of year 2017-12-13, cycle day 8
# record day of year 2017-12-14, cycle day 9
# record day of year 2017-12-15, cycle day 0
# record day of year 2017-12-16, cycle day 1
# record day of year 2017-12-17, cycle day 2
# record day of year 2017-12-18, cycle day 3
# record day of year 2017-12-19, cycle day 4
# record day of year 2017-12-20, cycle day 5
# record day of year 2017-12-21, cycle day 6
# record day of year 2017-12-22, cycle day 7
# record day of year 2017-12-23, cycle day 8
# record day of year 2017-12-24, cycle day 9
# record day of year 2017-12-25, cycle day 0
# record day of year 2017-12-26, cycle day 1
# record day of year 2017-12-27, cycle day 2
# record day of year 2017-12-28, cycle day 3
# record day of year 2017-12-29, cycle day 4
# record day of year 2017-12-30, cycle day 5
# record day of year 2017-12-31, cycle day 6
# 112.77554106712341

# %%
# Loop through all days
for f in range(len(ECCO_SSH.time)):
    
    # get the date/time associated with this record
    rec_time = ECCO_SSH.time[f]
    
    # Determine which cycle day we're in
    # ... count how many days since 1992-01-01?
    delta_days = int((rec_time.values - ECCO_start_time)/1e9/86400)
    
    # ... cycle day is delta_days mod 10
    cycle_day = delta_days % 10
    
    print(f'record day of year {str(rec_time.values)[0:10]}, cycle day {cycle_day}')
        
    # sample the ECCO field at the x,y locations for this cycle day 
    # search within a 200 km radius for the nearest neighbor.
    # (overkill since it's a 1 degree model but just to be safe)
    
    ECCO_at_xy_points =\
        kd_tree.resample_nearest(ECCO_grid_def, \
                                 ECCO_SSH[f].values, \
                                 alongtrack_swath[cycle_day],\
                                 radius_of_influence=200000)
  
    # make a new DataArray object
    ECCO_at_xy_points_da = xr.DataArray(ECCO_at_xy_points, dims=['i'])
    ECCO_at_xy_points_da = ECCO_at_xy_points_da.assign_coords({'time':rec_time})
    ECCO_at_xy_points_da = ECCO_at_xy_points_da.assign_coords({'cycle_day':cycle_day})
    ECCO_at_xy_points_da = ECCO_at_xy_points_da.assign_coords({'delta_days':delta_days})
    ECCO_at_xy_points_da = ECCO_at_xy_points_da.assign_coords({'lon':('i', x_track_in_d[cycle_day])})
    ECCO_at_xy_points_da = ECCO_at_xy_points_da.assign_coords({'lat':('i', y_track_in_d[cycle_day])})
    ECCO_at_xy_points_da.delta_days.attrs['comment'] = 'days since 1992-01-01'
    ECCO_at_xy_points_da.cycle_day.attrs['comment'] = 'which day in 10 day cycle'
    
    ECCO_at_xy_points_da.name = 'SSH_at_xy'
    ECCO_at_xy_points_da.attrs['source']='ECCO V4r4'

    # Save to Disk
    new_fname = 'ECCO_V4r4_alongtrack_SSH_' + str(rec_time.values).split('T')[0] + '.nc'
    ECCO_at_xy_points_da.to_netcdf(output_dir / new_fname)

# %%
ECCO_at_xy_points_da

# %% [markdown]
# # Plot Results for One Cycle Day

# %%
# This is the last processed day 

fig = plt.figure(figsize=(10,5))
cm = plt.get_cmap('gist_rainbow')
ax=fig.gca()

ax = plt.axes(projection=ccrs.Robinson( \
              central_longitude=-67, globe=None))
ax.gridlines()
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.COASTLINE)

kk=3
p=ax.scatter(ECCO_at_xy_points_da.lon[::kk],\
             ECCO_at_xy_points_da.lat[::kk], \
             c=ECCO_at_xy_points_da[::kk], s=10,\
             transform=ccrs.PlateCarree(),vmin=-1,vmax=1, cmap='jet')
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:825: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:877: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:944: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)

# %%
# and the original mapped SSH field 
fig = plt.figure(figsize=(10,5))
cm = plt.get_cmap('gist_rainbow')
ax=fig.gca()

ax = plt.axes(projection=ccrs.Robinson( \
              central_longitude=-67, globe=None))
ax.gridlines()
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.COASTLINE)

p=ax.pcolormesh(ECCO_lons, ECCO_lats,ECCO_SSH[f],
              transform=ccrs.PlateCarree(), cmap='jet',vmin=-1,vmax=1)
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1797: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   result = matplotlib.axes.Axes.pcolormesh(self, *args, **kwargs)

# %% [markdown]
# # Plot 10 days of along track SSH

# %%
ECCO_alongtrack_files = np.sort(list(output_dir.glob('*ECCO_V4r4_alongtrack_SSH_' + str(year) + '*nc')))

# %%
tmp = []
# any 10 sequential days comprises one full cycle
for d in range(10):
    tmp.append(xr.open_dataset(ECCO_alongtrack_files[d]))
    print(ECCO_alongtrack_files[d])
# Out:
# /home/jovyan/Data/ECCO_GMSL/ECCO_V4r4_alongtrack_output/ECCO_V4r4_alongtrack_SSH_2017-01-01.nc
# /home/jovyan/Data/ECCO_GMSL/ECCO_V4r4_alongtrack_output/ECCO_V4r4_alongtrack_SSH_2017-01-02.nc
# /home/jovyan/Data/ECCO_GMSL/ECCO_V4r4_alongtrack_output/ECCO_V4r4_alongtrack_SSH_2017-01-03.nc
# /home/jovyan/Data/ECCO_GMSL/ECCO_V4r4_alongtrack_output/ECCO_V4r4_alongtrack_SSH_2017-01-04.nc
# /home/jovyan/Data/ECCO_GMSL/ECCO_V4r4_alongtrack_output/ECCO_V4r4_alongtrack_SSH_2017-01-05.nc
# /home/jovyan/Data/ECCO_GMSL/ECCO_V4r4_alongtrack_output/ECCO_V4r4_alongtrack_SSH_2017-01-06.nc
# /home/jovyan/Data/ECCO_GMSL/ECCO_V4r4_alongtrack_output/ECCO_V4r4_alongtrack_SSH_2017-01-07.nc
# /home/jovyan/Data/ECCO_GMSL/ECCO_V4r4_alongtrack_output/ECCO_V4r4_alongtrack_SSH_2017-01-08.nc
# /home/jovyan/Data/ECCO_GMSL/ECCO_V4r4_alongtrack_output/ECCO_V4r4_alongtrack_SSH_2017-01-09.nc
# /home/jovyan/Data/ECCO_GMSL/ECCO_V4r4_alongtrack_output/ECCO_V4r4_alongtrack_SSH_2017-01-10.nc

# %%
fig = plt.figure(figsize=(15,5))
cm = plt.get_cmap('gist_rainbow')
ax=fig.gca()

ax = plt.axes(projection=ccrs.Robinson( \
              central_longitude=-67, globe=None))
ax.gridlines()
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.COASTLINE)

kk=12

for d in range(10):
    ECCO_at_xy = tmp[d].SSH_at_xy
    print(f'adding cycle day {ECCO_at_xy.cycle_day.values}')

    p=ax.scatter(ECCO_at_xy.lon[::kk],\
                 ECCO_at_xy.lat[::kk], \
                 c=ECCO_at_xy[::kk], s=1,\
                 transform=ccrs.PlateCarree(),
                 vmin=-1,vmax=1, cmap='jet')
# Out:
# adding cycle day 2
# adding cycle day 3
# adding cycle day 4
# adding cycle day 5
# adding cycle day 6
# adding cycle day 7
# adding cycle day 8
# adding cycle day 9
# adding cycle day 0
# adding cycle day 1
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:825: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:877: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:944: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
# /srv/conda/envs/notebook/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
